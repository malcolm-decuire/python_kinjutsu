# %%
##Journal##

#As of 5/29 I don't have access to streamlit, once I do then I can do all the web application stuff 
#5/29 learned about parser erros https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.errors.ParserWarning.html
#5/29 confirming that I cannot see my data
#5/30 t1-figure out error 'Missing column provided to 'parse_dates': 'Date''
#5/30 t2-try this out https://towardsdatascience.com/4-tricks-you-should-know-to-parse-date-columns-with-pandas-read-csv-27355bb2ad0e
#5/30 t3-try this out https://stackoverflow.com/questions/62875036/has-pandas-read-csv-date-parsing-options-changed-how-can-we-use-parse-dates-wit
#5/30 t4-t3 worked but now I'm getting an empty dataframe bc I'm using the url way
#5/30 t4a-this didn't work https://stackoverflow.com/questions/66431761/empty-dataframe-after-being-populated-from-url
#5/30 t5-trying populate data bc as of now its an empty dataframe
#5/30 t6- got this issue https://stackoverflow.com/questions/65022474/pd-read-csv-parsererror-error-tokenizing-data-c-error-expected-1-fields-in-l?noredirect=1&lq=1
#5/30 t7- Error tokenizing data http://net-informations.com/ds/err/token.htm
#5/30 t8-Expected 1 fields in line 367, saw 2. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
#5/30 t9- got this error ValueError: time data '0.2389' does not match format '%Y-%m-%d %H:%M:%S
#5/30 t10- got this error strptime() argument 1 must be str, not numpy.ndarray
#5/30 t11- try this out? Moved print(df1) can confirm data will show 
#5/30 t12- got this error now 'Timestamp' object has no attribute 'IvCall30'  -> try this https://pandas.pydata.org/pandas-docs/version/0.21/generated/pandas.Timestamp.to_datetime.html
#5/30 t13- just realized in the MasteringML example his data is not formatted like mine so thats he used that for loop
#5/30 t14- got this error unexpected EOF while parsing -> try this 
#5/30 t15- got this issue after cleaning up variable -> 'DataFrame' object has no attribute 'value'
#5/30 t16- new error - only size-1 arrays can be converted to Python scalars try this ->https://www.pythonpool.com/only-size-1-arrays-can-be-converted-to-python-scalars-error-solved/#:~:text=using%20this%20module.-,Only%20Size%201%20Arrays%20Can%20Be%20Converted%20To%20Python%20Scalars,are%20only%20a%20scalar%20value.
#5/30 t17- in the example he is only using month and sales vs day+lvCall+skew+etc -> must figure out to turn df into multi dim np array
#5/30 t18- try Vector Auto Regression https://www.analyticsvidhya.com/blog/2018/09/multivariate-time-series-guide-forecasting-modeling-python-codes/#:~:text=A%20Multivariate%20time%20series%20has,used%20for%20forecasting%20future%20values.
#5/30 t19- got this issue ''DataFrame' object has no attribute 'Date' -> try this https://stackoverflow.com/questions/61256171/pandas-dataframe-column-not-showing-on-df-columns
#5/30 t19a- looks like the date is the index and must be changed 
#5/30 t20- got this error after trying RSME -> Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).
#5/30 t21- BC i plan to use the dates as a continous predictor I need to convert that column to int or float
#5/30 t22- Got this error for RSME 'SVD did not converge in Linear Least Squares' try this -> https://stackoverflow.com/questions/40217369/python-linear-regression-predict-by-date
#5/30 t23- Converted date to float but still getting erros https://stackoverflow.com/questions/40217369/python-linear-regression-predict-by-date
#5/30 t25- Try this out https://stackoverflow.com/questions/27309243/python-statsmodels-arima-linalgerror-svd-did-not-converge
#5/30 t26- got this error endog is required to have ndim 1 but has ndim 2 -> 
#5/30 t27- got this error -> 'int' object has no attribute 'values'
#6/7 t28-  Decided to go from multivariate analysis to univariate analysis for the sake of simplicity and to get the app running
#6/7 t29- Reorganized Juptyer notebook to reflect my simpler approach to supervised learning using time series data
#6/7 t30- Got this error after successfully doing a lot of the RSME -> Input contains NaN, infinity or a value too large for dtype('float32').
#6/7 t31- RSME will show but cant run rsme = sqrt(mean_squared_error(test, predictions))
#6/7 t32- Look into doing calculations w/ NaN -> https://stackoverflow.com/questions/32217405/getting-python-pandas-dropna-method-to-work-with-n-a-values
#6/7 t33- Lets try this -> https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html
#6/7 t34- Tried adding skip_blank_lines in df.read csv but stil getting error
#6/7 t35- Still get error that cant convert string to 'na_filter=False,' when added to pd.read
#6/7 t36- still get -> Input contains NaN, infinity or a value too large for dtype('float32')
#6/7 t36- finna try 'na filter'
#6/7 t40- this still gives me a FREAKING ERROR! 
#6/7 t41- used dropna and it still shows nan when I print them 
#6/7 t42- this page worked https://stackabuse.com/python-how-to-handle-missing-dataframe-values-in-pandas
#6/7 t43- Finally got Time Series analyzed once I figured out how to treat non-zeros and host data, and clean up data
#6/7 t44- wanted to make ACF plots look clean and spaced. out
#6/7 t45- Getting errors ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals ConvergenceWarning) when doing manual arima 
#6/7 t46- will be limiting warnings for data over 1K lines going forward for ARIMA https://stackoverflow.com/questions/34444607/how-to-ignore-statsmodels-maximum-likelihood-convergence-warning
#6/7 t47- runtime for manual ARIMA is over 10 mins on XLI dataset for univariate analysis 
#6/8 t48- cant complete step 31.6.3 Grid Hyperparameter search -> it doesn't do anything -> after 60 mins it doesnt run or produce a result 
#6/8 t49- will try to run all one more time -> then just upload to github and record via quicktime. at 2:30 tried to run all 
#6/8 t50- after 40 mins of running, grid arima doesn't load
#6/8 t51- Research into ARIMA requires deeper knowledge of statsmodel and higher stats
#6/9 t52- Research https://en.wikipedia.org/wiki/Box%E2%80%93Jenkins_method

# %% [markdown]
# # 1) Problem Description

# %% [markdown]
# ### -Predict lvCall levels for SPDR XLI. Data goes from March 2002- Jan 2021
# ### -Values are implied volatility for the at-the-money (ATM) call for the stock with an expiration of n calendar days from the measurement date.
# ### -Nearly 4.4k observations
# ##### source: https://www.quandl.com/data/VOL-US-Equity-Historical-Option-Implied-Volatilities/documentation

# %% [markdown]
# # 2) Test Harness

# %% [markdown]
# ### -Validation: Dataset isn't current so we will pretend:
#     **From March 2002 through Feb 2020 (pre-pandemic)
#     **From Feb 2020 through Jan 2021 (pandemic times)

# %%
# Setup
import warnings 
import pandas as pd
import numpy as np
import time
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt
from matplotlib import pyplot
# %matplotlib inline 
from pandas import DataFrame
from pandas import read_csv
from datetime import datetime 

#load data & print sanity check 
url = 'https://raw.githubusercontent.com/malcolm-decuire/python_kinjutsu/main/SPDR_INDUSTRIAL%20SECTOR_VOL-XLI_lite_2columns.csv%20-%20SPDR_INDUSTRIAL%20SECTOR_VOL-XLI.csv'
dateparse = lambda x: datetime.strptime(x, '%Y-%m-%d')
df = pd.read_csv(url, sep='[;,]', engine='python', header=0, index_col=0, date_parser=dateparse, skip_blank_lines=True, na_values="nan,")
df1 = df.dropna(axis=0,inplace=True, how='all')

#quick sanity check
df1 = df.head(5)
df2 = df.values
print(df1)
df.dtypes

# seperate out a validation dataset
split_point = len(df) - 380
dataset, validation = df[0:split_point], df[split_point:]
dataset.to_csv('dataset.csv', header=False)
validation.to_csv('validation.csv', header=False)

print('Dataset %d, Validation %d' % (len(dataset), len(validation)))
# Out:
#             IvCall30
# Date
# 2021-01-15    0.2389
# 2021-01-14    0.2335
# 2021-01-13    0.2379
# 2021-01-12    0.2392
# 2021-01-11    0.2409
# Dataset 4349, Validation 380

# %% [markdown]
# ### -Model Evalution
#     **Going to use RSME per Dr. Brownlee

# %% [markdown]
# # 3) Persistence

# %% [markdown]
# ### -Time-Series Analysis requires a baseline of performance before jumping into Data Analysis
# ### -Baseline predictions for time series is called naive forecasting
#     **Intuition: Tryna use observation from previous time step to to predict next time step

# %%
#evaluate a persistence model 
import warnings 
import pandas as pd
import numpy as np
import time
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt
from matplotlib import pyplot
# %matplotlib inline 
from pandas import DataFrame
from pandas import read_csv
from datetime import datetime 

#load data & print sanity check 
url = 'https://raw.githubusercontent.com/malcolm-decuire/python_kinjutsu/main/SPDR_INDUSTRIAL%20SECTOR_VOL-XLI_lite_2columns.csv%20-%20SPDR_INDUSTRIAL%20SECTOR_VOL-XLI.csv'
dateparse = lambda x: datetime.strptime(x, '%Y-%m-%d')
df = pd.read_csv(url, sep='[;,]', engine='python', header=0, index_col=0, date_parser=dateparse, skip_blank_lines=True, na_values="nan,")
df1 = df.dropna(axis=0,inplace=True, how='all')


#prepare data
X= df.values
X= X.astype('float32')
train_size = int(len(X) * 0.50)
train, test = X[0:train_size], X[train_size:]
#walk forward validation
history = [x for x in train]
predictions = list()
for i in range (len(test)):
    #predict
    yhat= history[-1]
    predictions.append(yhat)
    #observation
    obs = test[i]
    history.append(obs)
    print('Predicted=%.3f, Expected=%.3f' % (yhat, obs))
#report performance    
rsme = sqrt(mean_squared_error(test, predictions))
print('RSME: %.3f' % rsme)
# Out:
# Predicted=0.319, Expected=0.320
# Predicted=0.320, Expected=0.302
# Predicted=0.302, Expected=0.319
# Predicted=0.319, Expected=0.351
# Predicted=0.351, Expected=0.397
# Predicted=0.397, Expected=0.347
# Predicted=0.347, Expected=0.365
# Predicted=0.365, Expected=0.412
# Predicted=0.412, Expected=0.429
# Predicted=0.429, Expected=0.435
# Predicted=0.435, Expected=0.311
# Predicted=0.311, Expected=0.331
# Predicted=0.331, Expected=0.312
# Predicted=0.312, Expected=0.379
# Predicted=0.379, Expected=0.423
# Predicted=0.423, Expected=0.528
# Predicted=0.528, Expected=0.391
# Predicted=0.391, Expected=0.478
# Predicted=0.478, Expected=0.362
# Predicted=0.362, Expected=0.405
# Predicted=0.405, Expected=0.238
# Predicted=0.238, Expected=0.271
# Predicted=0.271, Expected=0.261
# Predicted=0.261, Expected=0.264
# Predicted=0.264, Expected=0.244
# Predicted=0.244, Expected=0.233
# Predicted=0.233, Expected=0.213
# Predicted=0.213, Expected=0.210
# Predicted=0.210, Expected=0.204
# ...

# %% [markdown]
# #### Insight
#     *AN RSME of 0.03 indicates the model was wrong about 0.03 basis-points/day per prediction made

# %% [markdown]
# # 4) Data Analysis

# %% [markdown]
# 1. Summary Statistics.
# 2. Line Plot.
# 3. Density Plots.
# 4. Box and Whisker Plot.

# %% [markdown]
# ## Summary Stats

# %%
# summary statistics of time series
from pandas import read_csv
series = read_csv('dataset.csv', header=None, index_col=0, parse_dates=True, squeeze=True) 
print(series.describe())
# Out:
# count    4349.000000
# mean        0.182557
# std         0.091949
# min         0.073300
# 25%         0.126400
# 50%         0.152400
# 75%         0.209200
# max         0.941600
# Name: 1, dtype: float64

# %% [markdown]
# ### Observations from Summary Stat
#     1. # of obs (count) stayed the same even when removed the nan
#     2. the mean is around 0.18 to 0.20, gives a sense of threshold
#     3. std and percentiles indicate a lot variance between the low and high

# %% [markdown]
# ### Line Plot

# %%
# line plot of time series
from pandas import read_csv
series = read_csv('dataset.csv', header=None, index_col=0, parse_dates=True, squeeze=True) 
print(series.describe())
series.plot()
pyplot.show()
# Out:
# count    4349.000000
# mean        0.182557
# std         0.091949
# min         0.073300
# 25%         0.126400
# 50%         0.152400
# 75%         0.209200
# max         0.941600
# Name: 1, dtype: float64

# %% [markdown]
# ### Observations from Line Plot
#     1. Big jumps around market crashes (not surprising)
#     2. General trend upward
#     3. Given my domain expertise, I know that the manufacturing industry has a high beta (0.9-1.2)
# #### source: http://pages.stern.nyu.edu/~adamodar/New_Home_Page/datafile/Betas.html

# %% [markdown]
# ### Density Plot

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('dataset.csv', header=None, index_col=0, parse_dates=True, squeeze=True) 
pyplot.figure(1)
pyplot.subplot(211)
series.hist()
pyplot.subplot(212)
series.plot(kind='kde')
pyplot.show()

# %% [markdown]
# ### Observations from Density Plot
#     1. Distribution is not Gaussian, skewed
#     2. Distribution has a long right tail which may suggest exponential or something wonky
#     3. Need further investigation
#     4. Doing a box and whisker plot on this dataset maybe to messy to visualize

# %% [markdown]
# # 5) ARIMA MODELS

# %% [markdown]
# ### Manually Configure the ARIMA

# %%
# create and summarize a stationary version of the time series
from pandas import read_csv
from pandas import Series
from statsmodels.tsa.stattools import adfuller
from matplotlib import pyplot
# create a differenced series
def difference(dataset):
  diff = list()
  for i in range(1, len(dataset)):
    value = dataset[i] - dataset[i - 1]
    diff.append(value)
  return Series(diff)
series = read_csv('dataset.csv', header=None, index_col=0, parse_dates=True, squeeze=True) 
X = series.values
X = X.astype('float32')

# difference data
stationary = difference(X) 
stationary.index = series.index[1:]

# check if stationary
result = adfuller(stationary) 
print('ADF Statistic: %f' % result[0]) 
print('p-value: %f' % result[1]) 
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value)) 

# plot differenced data
stationary.plot()
pyplot.show()
# save
stationary.to_csv('stationary.csv', header=False)
# Out:
# ADF Statistic: -15.258574
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567

# %% [markdown]
# ### Autocorrelation Function & Partial Autocorrelation Function Plots

# %%
# ACF and PACF plots of the time series
from pandas import read_csv
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from matplotlib import pyplot
series = read_csv('dataset.csv', header=None, index_col=0, parse_dates=True, squeeze=True) 

pyplot.figure()
pyplot.subplot(211)
plot_acf(series, lags=20, ax=pyplot.gca())
pyplot.subplot(212)
plot_pacf(series, lags=20, ax=pyplot.gca())

#cleaned up the plot spacing
pyplot.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
pyplot.show()

# %% [markdown]
# ###  !!CAUTION!!: COMPLETE MANUAL ARIMA TAKES 30-40 MINS

# %%
# evaluate a manually configured ARIMA model
import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning
warnings.simplefilter('ignore', ConvergenceWarning)
from pandas import read_csv
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima.model import ARIMA
from math import sqrt

# load data
series = read_csv('dataset.csv', header=None, index_col=0, parse_dates=True, squeeze=True) 

# prepare data
X = series.values
X = X.astype('float32')
train_size = int(len(X) * 0.50)
train, test = X[0:train_size], X[train_size:]

# walk-forward validation
history = [x for x in train]
predictions = list()
for i in range(len(test)):
    # predict
    model = ARIMA(history, order=(4,1,1))
    model_fit = model.fit()
    yhat = model_fit.forecast()[0]
    predictions.append(yhat)
    # obersvations
    obs = test[i]
    history.append(obs)
    print('>Predicted=%.3f, Expected=%.3f' % (yhat, obs))
    
#report performance
rmse = sqrt(mean_squared_error(test, predictions))
print('RMSE: %3.f' % rmse)
# Out:
# >Predicted=0.247, Expected=0.252
# >Predicted=0.250, Expected=0.262
# >Predicted=0.256, Expected=0.217
# >Predicted=0.231, Expected=0.228
# >Predicted=0.228, Expected=0.211
# >Predicted=0.215, Expected=0.258
# >Predicted=0.249, Expected=0.224
# >Predicted=0.226, Expected=0.211
# >Predicted=0.223, Expected=0.216
# >Predicted=0.209, Expected=0.215
# >Predicted=0.223, Expected=0.233
# >Predicted=0.223, Expected=0.240
# >Predicted=0.237, Expected=0.209
# >Predicted=0.217, Expected=0.222
# >Predicted=0.220, Expected=0.221
# >Predicted=0.220, Expected=0.203
# >Predicted=0.212, Expected=0.206
# >Predicted=0.204, Expected=0.206
# >Predicted=0.208, Expected=0.193
# >Predicted=0.198, Expected=0.194
# >Predicted=0.195, Expected=0.180
# >Predicted=0.185, Expected=0.176
# >Predicted=0.180, Expected=0.165
# >Predicted=0.168, Expected=0.169
# >Predicted=0.171, Expected=0.173
# >Predicted=0.171, Expected=0.159
# >Predicted=0.165, Expected=0.173
# >Predicted=0.169, Expected=0.179
# ...

# %% [markdown]
# ### Observations from Manual RSME
#     1. AN RSME of 0 means the model couldn't do a better job than a persistence model
#     2. Because this dataset is large I may need to explore more efficient methods of analysis and modeling
#     3. Give that the problem was trying to predict 30day-ATM volitality it makes sense how difficult DS is

# %% [markdown]
# ### Grid Search ARIMA Hyperparameters
#     1. ACF & PACF suggest that the persistence model is the best performer
#     2. We are going to confirm that this is the case
#     3. I have to read more about ARIMA hyperparameters & skip over hyperparameter combos that dont converge
#     4. We are searching for valudes of p,d,q
#     5. Note it took over 10 mins.

# %%
# grid search ARIMA parameters for a time series
import warnings
from pandas import read_csv
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt

# evaluate an ARIMA model for a given order (p,d,q) and return RMSE
def evaluate_arima_model(X, arima_order):
    # prepare training dataset
    X = X.astype('float32')
    train_size = int(len(X) * 0.50)
    train, test = X[0:train_size], X[train_size:]
    history = [x for x in train]
    # make predictions
    predictions = list()
    for t in range(len(test)):
        model = ARIMA(history, order=arima_order)
        model_fit = model.fit()
        yhat = model_fit.forecast()[0]
        predictions.append(yhat)
        history.append(test[t])
    # calculate out of sample error
    rmse = sqrt(mean_squared_error(test, predictions))
    return rmse

# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
    dataset = dataset.astype('float32')
    best_score, best_cfg = float("inf"), None
    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p,d,q)
                try:
                    rmse = evaluate_arima_model(dataset, order)
                    if rmse < best_score:
                        best_score, best_cfg = rmse, order
                    print('ARIMA%s RMSE=%.3f' % (order,rmse))
                except:
                    continue
    print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))

# load dataset
series = read_csv('dataset.csv', header=None, index_col=0, parse_dates=True, squeeze=True)
# evaluate parameters
p_values = range(0, 5)
d_values = range(0, 3)
q_values = range(0, 5)
warnings.filterwarnings("ignore")
evaluate_models(series.values, p_values, d_values, q_values)

# %% [markdown]
# # 6) Model Validation

# %% [markdown]
# ### Finalize Model: Train & save the final model
